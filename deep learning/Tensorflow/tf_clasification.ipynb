# %%
import tensorflow as tf

# %%
import pandas as pd
import numpy as np

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
cols_to_norm  = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x-x.min())/(x.max()-x.min() ))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
num_preg
# Out:
# NumericColumn(key='Number_pregnant', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])

# %%
#this technique is used when we dont know the actual no. of classes in the column we just pass the max bucket size
#assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group',hash_bucket_size=10)

# %%
import matplotlib.pyplot as plt

# %%
diabetes['Age'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
age_bucket = tf.feature_column.bucketized_column(age,boundaries=[20,30,40,50,60,70,80])

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_bucket]

# %%
from sklearn.model_selection import train_test_split

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data, labels, test_size=0.3, random_state=101)

# %%
input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x = X_train,
                                                 y = y_train,
                                                 batch_size = 10,
                                                 num_epochs = 1000,
                                                 shuffle = True)

# %%
model  = tf.estimator.LinearClassifier(feature_columns = feat_cols,n_classes=2,)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\PRAMEE~1\AppData\Local\Temp\tmptvn5e28c
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\PRAMEE~1\\AppData\\Local\\Temp\\tmptvn5e28c', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\PRAMEE~1\AppData\Local\Temp\tmptvn5e28c\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.6931472, step = 0
# INFO:tensorflow:global_step/sec: 195.051
# INFO:tensorflow:loss = 0.43471774, step = 100 (0.516 sec)
# INFO:tensorflow:global_step/sec: 235.994
# INFO:tensorflow:loss = 0.7015778, step = 200 (0.423 sec)
# INFO:tensorflow:global_step/sec: 168.855
# INFO:tensorflow:loss = 0.6905488, step = 300 (0.595 sec)
# INFO:tensorflow:global_step/sec: 164.562
# INFO:tensorflow:loss = 0.50838417, step = 400 (0.611 sec)
# INFO:tensorflow:global_step/sec: 144.756
# INFO:tensorflow:loss = 0.58771116, step = 500 (0.692 sec)
# INFO:tensorflow:global_step/sec: 189.225
# INFO:tensorflow:loss = 0.43946916, step = 600 (0.523 sec)
# INFO:tensorflow:global_step/sec: 162.021
# INFO:tensorflow:loss = 0.62746364, step = 700 (0.625 sec)
# INFO:tensorflow:global_step/sec: 141.019
# INFO:tensorflow:loss = 0.73471344, step = 800 (0.701 sec)
# INFO:tensorflow:global_step/sec: 152.838
# INFO:tensorflow:loss = 0.5956423, step = 900 (0.654 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\PRAMEE~1\AppData\Local\Temp\tmptvn5e28c\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Loss for final step: 0.623834.

# %%
eval_input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x = X_test,
                                                                y = y_test,
                                                                batch_size = 10,
                                                                num_epochs = 1,
                                                                shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-06-03T10:53:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\PRAMEE~1\AppData\Local\Temp\tmptvn5e28c\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.93828s
# INFO:tensorflow:Finished evaluation at 2021-06-03-10:53:19
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.74458873, accuracy_baseline = 0.64935064, auc = 0.8033334, auc_precision_recall = 0.6509454, average_loss = 0.52489233, global_step = 1000, label/mean = 0.35064936, loss = 0.5233143, precision = 0.671875, prediction/mean = 0.36162242, recall = 0.5308642
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\PRAMEE~1\AppData\Local\Temp\tmptvn5e28c\model.ckpt-1000

# %%
print(results)
# Out:
# {'accuracy': 0.74458873, 'accuracy_baseline': 0.64935064, 'auc': 0.8033334, 'auc_precision_recall': 0.6509454, 'average_loss': 0.52489233, 'label/mean': 0.35064936, 'loss': 0.5233143, 'precision': 0.671875, 'prediction/mean': 0.36162242, 'recall': 0.5308642, 'global_step': 1000}

# %%
#tf.compat.v1.estimator.inputs.pandas_input_fn

# %%
pred_input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x = X_test,
                                                                batch_size=10,
                                                                num_epochs=1,
                                                                shuffle=False)

# %%
pred = model.predict(pred_input_func)

# %%
list(pred)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\PRAMEE~1\AppData\Local\Temp\tmptvn5e28c\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.08311427], dtype=float32),
#   'logistic': array([0.5207666], dtype=float32),
#   'probabilities': array([0.47923338, 0.5207666 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.47223413], dtype=float32),
#   'logistic': array([0.6159124], dtype=float32),
#   'probabilities': array([0.3840876, 0.6159124], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.50327224], dtype=float32),
#   'logistic': array([0.376772], dtype=float32),
#   'probabilities': array([0.623228, 0.376772], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.67919445], dtype=float32),
#   'logistic': array([0.33644116], dtype=float32),
#   'probabilities': array([0.6635589, 0.3364411], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.707371], dtype=float32),
#   'logistic': array([0.15350503], dtype=float32),
#   'probabilities': array([0.846495  , 0.15350503], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7243744], dtype=float32),
#   'logistic': array([0.67356956], dtype=float32),
#   'probabilities': array([0.32643044, 0.67356956], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3604524], dtype=float32),
#   'logistic': array([0.58914995], dtype=float32),
#   'probabilities': array([0.41085005, 0.58914995], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7167129], dtype=float32),
#   'logistic': array([0.32811725], dtype=float32),
#   'probabilities': array([0.67188275, 0.32811722], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1604966], dtype=float32),
#   'logistic': array([0.2385771], dtype=float32),
#   'probabilities': array([0.76142293, 0.23857705], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.127966], dtype=float32),
#   'logistic': array([0.24453664], dtype=float32),
#   'probabilities': array([0.75546336, 0.24453665], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8220086], dtype=float32),
#   'logistic': array([0.13919306], dtype=float32),
#   'probabilities': array([0.860807  , 0.13919304], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6453297], dtype=float32),
#   'logistic': array([0.16174114], dtype=float32),
#   'probabilities': array([0.83825886, 0.16174115], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.87463975], dtype=float32),
#   'logistic': array([0.29428983], dtype=float32),
#   'probabilities': array([0.70571023, 0.2942898 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.1852938], dtype=float32),
#   'logistic': array([0.54619133], dtype=float32),
#   'probabilities': array([0.45380867, 0.5461914 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4850681], dtype=float32),
#   'logistic': array([0.18466315], dtype=float32),
#   'probabilities': array([0.8153369 , 0.18466315], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6290128], dtype=float32),
#   'logistic': array([0.34773445], dtype=float32),
#   'probabilities': array([0.6522656 , 0.34773442], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5260103], dtype=float32),
#   'logistic': array([0.37144792], dtype=float32),
#   'probabilities': array([0.6285521 , 0.37144792], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.857917], dtype=float32),
#   'logistic': array([0.13494602], dtype=float32),
#   'probabilities': array([0.86505395, 0.13494603], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5685098], dtype=float32),
#   'logistic': array([0.36158073], dtype=float32),
#   'probabilities': array([0.6384193 , 0.36158076], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7189382], dtype=float32),
#   'logistic': array([0.152008], dtype=float32),
#   'probabilities': array([0.847992  , 0.15200798], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2812638], dtype=float32),
#   'logistic': array([0.21733513], dtype=float32),
#   'probabilities': array([0.78266484, 0.21733516], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.91028327], dtype=float32),
#   'logistic': array([0.2869419], dtype=float32),
#   'probabilities': array([0.7130581 , 0.28694186], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.54357004], dtype=float32),
#   'logistic': array([0.6326425], dtype=float32),
#   'probabilities': array([0.3673575, 0.6326425], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2739086], dtype=float32),
#   'logistic': array([0.21858889], dtype=float32),
#   'probabilities': array([0.7814111, 0.2185889], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4486618], dtype=float32),
#   'logistic': array([0.19020757], dtype=float32),
#   'probabilities': array([0.8097924, 0.1902076], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1064647], dtype=float32),
#   'logistic': array([0.7514695], dtype=float32),
#   'probabilities': array([0.24853055, 0.75146943], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5526347], dtype=float32),
#   'logistic': array([0.17470607], dtype=float32),
#   'probabilities': array([0.82529396, 0.17470607], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.75965405], dtype=float32),
#   'logistic': array([0.3187214], dtype=float32),
#   'probabilities': array([0.6812786 , 0.31872135], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0844347], dtype=float32),
#   'logistic': array([0.11061889], dtype=float32),
#   'probabilities': array([0.8893811 , 0.11061892], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2474544], dtype=float32),
#   'logistic': array([0.56154984], dtype=float32),
#   'probabilities': array([0.43845013, 0.56154984], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.4761348], dtype=float32),
#   'logistic': array([0.92245173], dtype=float32),
#   'probabilities': array([0.07754824, 0.92245173], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.38625222], dtype=float32),
#   'logistic': array([0.40461984], dtype=float32),
#   'probabilities': array([0.5953802 , 0.40461984], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7252938], dtype=float32),
#   'logistic': array([0.32622832], dtype=float32),
#   'probabilities': array([0.6737717 , 0.32622832], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.1046946], dtype=float32),
#   'logistic': array([0.52614975], dtype=float32),
#   'probabilities': array([0.47385028, 0.5261498 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1011404], dtype=float32),
#   'logistic': array([0.24952626], dtype=float32),
#   'probabilities': array([0.75047374, 0.24952629], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4840243], dtype=float32),
#   'logistic': array([0.3813023], dtype=float32),
#   'probabilities': array([0.6186977 , 0.38130233], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.06431782], dtype=float32),
#   'logistic': array([0.4839261], dtype=float32),
#   'probabilities': array([0.5160739 , 0.48392606], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.400962], dtype=float32),
#   'logistic': array([0.59891874], dtype=float32),
#   'probabilities': array([0.40108123, 0.59891874], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0525411], dtype=float32),
#   'logistic': array([0.74126256], dtype=float32),
#   'probabilities': array([0.25873744, 0.7412626 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6945825], dtype=float32),
#   'logistic': array([0.3330145], dtype=float32),
#   'probabilities': array([0.6669856 , 0.33301446], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5154657], dtype=float32),
#   'logistic': array([0.18013018], dtype=float32),
#   'probabilities': array([0.8198698 , 0.18013018], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.10078597], dtype=float32),
#   'logistic': array([0.52517515], dtype=float32),
#   'probabilities': array([0.47482485, 0.5251752 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6182189], dtype=float32),
#   'logistic': array([0.16545063], dtype=float32),
#   'probabilities': array([0.83454937, 0.16545065], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.01354325], dtype=float32),
#   'logistic': array([0.5033858], dtype=float32),
#   'probabilities': array([0.49661428, 0.5033858 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7318662], dtype=float32),
#   'logistic': array([0.15034902], dtype=float32),
#   'probabilities': array([0.84965104, 0.15034902], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9615874], dtype=float32),
#   'logistic': array([0.12329537], dtype=float32),
#   'probabilities': array([0.87670463, 0.12329535], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3410802], dtype=float32),
#   'logistic': array([0.58445287], dtype=float32),
#   'probabilities': array([0.41554707, 0.58445287], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4591908], dtype=float32),
#   'logistic': array([0.18859112], dtype=float32),
#   'probabilities': array([0.8114089 , 0.18859111], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3524542], dtype=float32),
#   'logistic': array([0.20546943], dtype=float32),
#   'probabilities': array([0.79453063, 0.20546946], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8666744], dtype=float32),
#   'logistic': array([0.13392699], dtype=float32),
#   'probabilities': array([0.866073  , 0.13392699], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.483429], dtype=float32),
#   'logistic': array([0.18491006], dtype=float32),
#   'probabilities': array([0.81508994, 0.18491006], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1492311], dtype=float32),
#   'logistic': array([0.24062955], dtype=float32),
#   'probabilities': array([0.75937045, 0.24062957], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0346513], dtype=float32),
#   'logistic': array([0.2621833], dtype=float32),
#   'probabilities': array([0.73781663, 0.26218334], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5712723], dtype=float32),
#   'logistic': array([0.36094332], dtype=float32),
#   'probabilities': array([0.63905674, 0.3609433 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8273649], dtype=float32),
#   'logistic': array([0.13855246], dtype=float32),
#   'probabilities': array([0.8614475 , 0.13855249], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1871938], dtype=float32),
#   'logistic': array([0.23376119], dtype=float32),
#   'probabilities': array([0.7662388, 0.2337612], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.279451], dtype=float32),
#   'logistic': array([0.21764371], dtype=float32),
#   'probabilities': array([0.78235626, 0.21764368], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2875266], dtype=float32),
#   'logistic': array([0.21627176], dtype=float32),
#   'probabilities': array([0.78372824, 0.21627176], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.09426308], dtype=float32),
#   'logistic': array([0.47645167], dtype=float32),
#   'probabilities': array([0.52354836, 0.4764517 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5727811], dtype=float32),
#   'logistic': array([0.17182031], dtype=float32),
#   'probabilities': array([0.82817966, 0.17182027], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2387968], dtype=float32),
#   'logistic': array([0.22464547], dtype=float32),
#   'probabilities': array([0.7753545 , 0.22464548], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.44888246], dtype=float32),
#   'logistic': array([0.6103735], dtype=float32),
#   'probabilities': array([0.3896265, 0.6103735], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4627992], dtype=float32),
#   'logistic': array([0.613678], dtype=float32),
#   'probabilities': array([0.38632202, 0.61367804], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.01453674], dtype=float32),
#   'logistic': array([0.49636588], dtype=float32),
#   'probabilities': array([0.5036341 , 0.49636585], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.54514134], dtype=float32),
#   'logistic': array([0.36699238], dtype=float32),
#   'probabilities': array([0.6330076 , 0.36699238], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.07532096], dtype=float32),
#   'logistic': array([0.48117867], dtype=float32),
#   'probabilities': array([0.51882136, 0.48117867], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4374111], dtype=float32),
#   'logistic': array([0.19194657], dtype=float32),
#   'probabilities': array([0.80805343, 0.19194658], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3630394], dtype=float32),
#   'logistic': array([0.20374677], dtype=float32),
#   'probabilities': array([0.7962532 , 0.20374677], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7311578], dtype=float32),
#   'logistic': array([0.1504395], dtype=float32),
#   'probabilities': array([0.84956044, 0.15043955], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8124561], dtype=float32),
#   'logistic': array([0.14034152], dtype=float32),
#   'probabilities': array([0.8596584 , 0.14034154], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3836342], dtype=float32),
#   'logistic': array([0.59474933], dtype=float32),
#   'probabilities': array([0.40525067, 0.59474933], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1691275], dtype=float32),
#   'logistic': array([0.23701277], dtype=float32),
#   'probabilities': array([0.76298726, 0.23701273], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.29546905], dtype=float32),
#   'logistic': array([0.42666548], dtype=float32),
#   'probabilities': array([0.5733345 , 0.42666548], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.26244354], dtype=float32),
#   'logistic': array([0.56523687], dtype=float32),
#   'probabilities': array([0.43476313, 0.56523687], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8385781], dtype=float32),
#   'logistic': array([0.30183434], dtype=float32),
#   'probabilities': array([0.69816566, 0.30183432], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4133507], dtype=float32),
#   'logistic': array([0.60189104], dtype=float32),
#   'probabilities': array([0.39810896, 0.60189104], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8660468], dtype=float32),
#   'logistic': array([0.1339998], dtype=float32),
#   'probabilities': array([0.86600024, 0.13399981], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3981881], dtype=float32),
#   'logistic': array([0.59825224], dtype=float32),
#   'probabilities': array([0.4017477 , 0.59825224], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8639834], dtype=float32),
#   'logistic': array([0.1342394], dtype=float32),
#   'probabilities': array([0.86576056, 0.13423944], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.13777292], dtype=float32),
#   'logistic': array([0.53438884], dtype=float32),
#   'probabilities': array([0.46561113, 0.53438884], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.66128194], dtype=float32),
#   'logistic': array([0.34045172], dtype=float32),
#   'probabilities': array([0.65954834, 0.34045172], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.586261], dtype=float32),
#   'logistic': array([0.16991055], dtype=float32),
#   'probabilities': array([0.8300894 , 0.16991058], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.17735863], dtype=float32),
#   'logistic': array([0.5442238], dtype=float32),
#   'probabilities': array([0.45577618, 0.5442238 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.31046104], dtype=float32),
#   'logistic': array([0.57699776], dtype=float32),
#   'probabilities': array([0.4230022, 0.5769978], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.17934358], dtype=float32),
#   'logistic': array([0.5447161], dtype=float32),
#   'probabilities': array([0.45528388, 0.5447161 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5895479], dtype=float32),
#   'logistic': array([0.16944748], dtype=float32),
#   'probabilities': array([0.83055246, 0.16944751], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.56572556], dtype=float32),
#   'logistic': array([0.36222374], dtype=float32),
#   'probabilities': array([0.6377763 , 0.36222374], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6881955], dtype=float32),
#   'logistic': array([0.15601328], dtype=float32),
#   'probabilities': array([0.8439867, 0.1560133], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.79800296], dtype=float32),
#   'logistic': array([0.6895471], dtype=float32),
#   'probabilities': array([0.31045288, 0.6895471 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3248469], dtype=float32),
#   'logistic': array([0.78998697], dtype=float32),
#   'probabilities': array([0.21001303, 0.78998697], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.45336354], dtype=float32),
#   'logistic': array([0.61143863], dtype=float32),
#   'probabilities': array([0.38856134, 0.61143863], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2682344], dtype=float32),
#   'logistic': array([0.21955967], dtype=float32),
#   'probabilities': array([0.78044033, 0.21955964], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.18608183], dtype=float32),
#   'logistic': array([0.4536133], dtype=float32),
#   'probabilities': array([0.54638666, 0.4536133 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.51520276], dtype=float32),
#   'logistic': array([0.37397468], dtype=float32),
#   'probabilities': array([0.6260253 , 0.37397465], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.22384793], dtype=float32),
#   'logistic': array([0.44427055], dtype=float32),
#   'probabilities': array([0.55572945, 0.44427052], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6113993], dtype=float32),
#   'logistic': array([0.35174006], dtype=float32),
#   'probabilities': array([0.64825994, 0.35174006], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.27360785], dtype=float32),
#   'logistic': array([0.4320216], dtype=float32),
#   'probabilities': array([0.5679784 , 0.43202156], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6443708], dtype=float32),
#   'logistic': array([0.1618712], dtype=float32),
#   'probabilities': array([0.8381288, 0.1618712], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.18819654], dtype=float32),
#   'logistic': array([0.54691076], dtype=float32),
#   'probabilities': array([0.45308924, 0.54691076], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.13271785], dtype=float32),
#   'logistic': array([0.5331308], dtype=float32),
#   'probabilities': array([0.46686915, 0.5331308 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1045746], dtype=float32),
#   'logistic': array([0.24888375], dtype=float32),
#   'probabilities': array([0.7511163 , 0.24888374], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4807035], dtype=float32),
#   'logistic': array([0.18532118], dtype=float32),
#   'probabilities': array([0.81467885, 0.1853212 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5508682], dtype=float32),
#   'logistic': array([0.17496088], dtype=float32),
#   'probabilities': array([0.8250391 , 0.17496091], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.92438346], dtype=float32),
#   'logistic': array([0.2840656], dtype=float32),
#   'probabilities': array([0.71593446, 0.28406557], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.56971353], dtype=float32),
#   'logistic': array([0.36130294], dtype=float32),
#   'probabilities': array([0.6386971 , 0.36130294], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7457974], dtype=float32),
#   'logistic': array([0.14857802], dtype=float32),
#   'probabilities': array([0.8514219 , 0.14857805], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.73703766], dtype=float32),
#   'logistic': array([0.32365227], dtype=float32),
#   'probabilities': array([0.67634773, 0.32365227], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.211959], dtype=float32),
#   'logistic': array([0.22935462], dtype=float32),
#   'probabilities': array([0.77064544, 0.22935462], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1778364], dtype=float32),
#   'logistic': array([0.10175851], dtype=float32),
#   'probabilities': array([0.89824146, 0.10175851], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8490548], dtype=float32),
#   'logistic': array([0.13598388], dtype=float32),
#   'probabilities': array([0.8640161 , 0.13598391], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.9601327], dtype=float32),
#   'logistic': array([0.72314835], dtype=float32),
#   'probabilities': array([0.27685162, 0.7231484 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5191143], dtype=float32),
#   'logistic': array([0.17959198], dtype=float32),
#   'probabilities': array([0.82040805, 0.179592  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8097236], dtype=float32),
#   'logistic': array([0.14067155], dtype=float32),
#   'probabilities': array([0.85932845, 0.14067152], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7185631], dtype=float32),
#   'logistic': array([0.15205634], dtype=float32),
#   'probabilities': array([0.8479436 , 0.15205634], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.03841102], dtype=float32),
#   'logistic': array([0.49039844], dtype=float32),
#   'probabilities': array([0.5096016 , 0.49039847], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2710371], dtype=float32),
#   'logistic': array([0.4326525], dtype=float32),
#   'probabilities': array([0.56734747, 0.43265247], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1546443], dtype=float32),
#   'logistic': array([0.23964182], dtype=float32),
#   'probabilities': array([0.7603582 , 0.23964182], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.25765395], dtype=float32),
#   'logistic': array([0.4359405], dtype=float32),
#   'probabilities': array([0.5640595, 0.4359405], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3939947], dtype=float32),
#   'logistic': array([0.19877076], dtype=float32),
#   'probabilities': array([0.80122924, 0.1987708 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1418095], dtype=float32),
#   'logistic': array([0.2419883], dtype=float32),
#   'probabilities': array([0.7580117 , 0.24198829], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.00291681], dtype=float32),
#   'logistic': array([0.4992708], dtype=float32),
#   'probabilities': array([0.5007292, 0.4992708], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.11333561], dtype=float32),
#   'logistic': array([0.47169638], dtype=float32),
#   'probabilities': array([0.5283036 , 0.47169638], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.75527], dtype=float32),
#   'logistic': array([0.14738369], dtype=float32),
#   'probabilities': array([0.85261625, 0.14738372], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4672752], dtype=float32),
#   'logistic': array([0.3852614], dtype=float32),
#   'probabilities': array([0.61473864, 0.3852614 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.60078514], dtype=float32),
#   'logistic': array([0.6458359], dtype=float32),
#   'probabilities': array([0.3541641 , 0.64583594], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.09490907], dtype=float32),
#   'logistic': array([0.5237095], dtype=float32),
#   'probabilities': array([0.47629055, 0.5237095 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4964471], dtype=float32),
#   'logistic': array([0.378376], dtype=float32),
#   'probabilities': array([0.62162405, 0.37837598], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2201134], dtype=float32),
#   'logistic': array([0.55480725], dtype=float32),
#   'probabilities': array([0.44519275, 0.55480725], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2632058], dtype=float32),
#   'logistic': array([0.22042254], dtype=float32),
#   'probabilities': array([0.7795775 , 0.22042252], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3667824], dtype=float32),
#   'logistic': array([0.2031402], dtype=float32),
#   'probabilities': array([0.79685986, 0.2031402 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7753965], dtype=float32),
#   'logistic': array([0.14487252], dtype=float32),
#   'probabilities': array([0.85512745, 0.14487252], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9847005], dtype=float32),
#   'logistic': array([0.27196008], dtype=float32),
#   'probabilities': array([0.72803986, 0.27196008], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.06543887], dtype=float32),
#   'logistic': array([0.48364612], dtype=float32),
#   'probabilities': array([0.5163539 , 0.48364612], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6207545], dtype=float32),
#   'logistic': array([0.65039015], dtype=float32),
#   'probabilities': array([0.34960985, 0.6503901 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1716247], dtype=float32),
#   'logistic': array([0.23656145], dtype=float32),
#   'probabilities': array([0.7634386 , 0.23656146], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5879853], dtype=float32),
#   'logistic': array([0.16966754], dtype=float32),
#   'probabilities': array([0.83033246, 0.16966754], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.36341828], dtype=float32),
#   'logistic': array([0.41013235], dtype=float32),
#   'probabilities': array([0.58986765, 0.41013238], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2219887], dtype=float32),
#   'logistic': array([0.22758669], dtype=float32),
#   'probabilities': array([0.7724133 , 0.22758667], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7569058], dtype=float32),
#   'logistic': array([0.14717826], dtype=float32),
#   'probabilities': array([0.85282165, 0.14717829], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.446455], dtype=float32),
#   'logistic': array([0.19054776], dtype=float32),
#   'probabilities': array([0.8094523 , 0.19054775], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8719099], dtype=float32),
#   'logistic': array([0.13332087], dtype=float32),
#   'probabilities': array([0.86667913, 0.1333209 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
# ...
#   'logistic': array([0.69924736], dtype=float32),
#   'probabilities': array([0.3007526 , 0.69924736], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9153671], dtype=float32),
#   'logistic': array([0.12837905], dtype=float32),
#   'probabilities': array([0.87162095, 0.12837909], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7481754], dtype=float32),
#   'logistic': array([0.14827746], dtype=float32),
#   'probabilities': array([0.8517225 , 0.14827748], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2686017], dtype=float32),
#   'logistic': array([0.21949673], dtype=float32),
#   'probabilities': array([0.7805033 , 0.21949673], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.73599464], dtype=float32),
#   'logistic': array([0.32388064], dtype=float32),
#   'probabilities': array([0.6761194 , 0.32388064], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5559476], dtype=float32),
#   'logistic': array([0.36448562], dtype=float32),
#   'probabilities': array([0.6355144 , 0.36448562], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.12080741], dtype=float32),
#   'logistic': array([0.5301652], dtype=float32),
#   'probabilities': array([0.46983483, 0.5301652 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.16566527], dtype=float32),
#   'logistic': array([0.5413219], dtype=float32),
#   'probabilities': array([0.4586781, 0.5413218], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.46081764], dtype=float32),
#   'logistic': array([0.38679188], dtype=float32),
#   'probabilities': array([0.6132081 , 0.38679188], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5998792], dtype=float32),
#   'logistic': array([0.35437134], dtype=float32),
#   'probabilities': array([0.6456287 , 0.35437137], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6035362], dtype=float32),
#   'logistic': array([0.35353512], dtype=float32),
#   'probabilities': array([0.64646494, 0.3535351 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4126406], dtype=float32),
#   'logistic': array([0.19581789], dtype=float32),
#   'probabilities': array([0.80418205, 0.19581789], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.39503753], dtype=float32),
#   'logistic': array([0.5974948], dtype=float32),
#   'probabilities': array([0.4025052, 0.5974948], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8564314], dtype=float32),
#   'logistic': array([0.13511953], dtype=float32),
#   'probabilities': array([0.86488044, 0.13511956], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1736803], dtype=float32),
#   'logistic': array([0.23619041], dtype=float32),
#   'probabilities': array([0.7638096 , 0.23619041], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.14382923], dtype=float32),
#   'logistic': array([0.53589547], dtype=float32),
#   'probabilities': array([0.46410453, 0.5358954 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6466108], dtype=float32),
#   'logistic': array([0.3437537], dtype=float32),
#   'probabilities': array([0.65624636, 0.3437537 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3673913], dtype=float32),
#   'logistic': array([0.20304164], dtype=float32),
#   'probabilities': array([0.7969583 , 0.20304163], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9280205], dtype=float32),
#   'logistic': array([0.2833265], dtype=float32),
#   'probabilities': array([0.71667355, 0.2833265 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0493163], dtype=float32),
#   'logistic': array([0.2593564], dtype=float32),
#   'probabilities': array([0.7406436, 0.2593564], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7706562], dtype=float32),
#   'logistic': array([0.14546075], dtype=float32),
#   'probabilities': array([0.8545393 , 0.14546074], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3364544], dtype=float32),
#   'logistic': array([0.20809373], dtype=float32),
#   'probabilities': array([0.7919063 , 0.20809375], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.17120898], dtype=float32),
#   'logistic': array([0.54269797], dtype=float32),
#   'probabilities': array([0.45730203, 0.542698  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.74519074], dtype=float32),
#   'logistic': array([0.67812985], dtype=float32),
#   'probabilities': array([0.32187015, 0.6781299 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4452058], dtype=float32),
#   'logistic': array([0.60949874], dtype=float32),
#   'probabilities': array([0.39050123, 0.60949874], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7171427], dtype=float32),
#   'logistic': array([0.6719775], dtype=float32),
#   'probabilities': array([0.32802248, 0.67197746], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2939583], dtype=float32),
#   'logistic': array([0.4270351], dtype=float32),
#   'probabilities': array([0.5729649, 0.4270351], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8712641], dtype=float32),
#   'logistic': array([0.29499137], dtype=float32),
#   'probabilities': array([0.7050087 , 0.29499134], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.00440252], dtype=float32),
#   'logistic': array([0.5011006], dtype=float32),
#   'probabilities': array([0.4988994 , 0.50110066], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4746907], dtype=float32),
#   'logistic': array([0.18623072], dtype=float32),
#   'probabilities': array([0.8137693 , 0.18623069], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6439989], dtype=float32),
#   'logistic': array([0.16192168], dtype=float32),
#   'probabilities': array([0.8380784 , 0.16192168], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4886253], dtype=float32),
#   'logistic': array([0.18412817], dtype=float32),
#   'probabilities': array([0.81587183, 0.18412815], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.09252417], dtype=float32),
#   'logistic': array([0.47688544], dtype=float32),
#   'probabilities': array([0.52311456, 0.47688544], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.7322724], dtype=float32),
#   'logistic': array([0.06109568], dtype=float32),
#   'probabilities': array([0.93890435, 0.06109568], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0535418], dtype=float32),
#   'logistic': array([0.25854558], dtype=float32),
#   'probabilities': array([0.7414544 , 0.25854555], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5105183], dtype=float32),
#   'logistic': array([0.18086201], dtype=float32),
#   'probabilities': array([0.819138, 0.180862], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0396194], dtype=float32),
#   'logistic': array([0.26122344], dtype=float32),
#   'probabilities': array([0.7387765 , 0.26122344], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1301222], dtype=float32),
#   'logistic': array([0.24413857], dtype=float32),
#   'probabilities': array([0.75586146, 0.24413855], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.92250526], dtype=float32),
#   'logistic': array([0.28444773], dtype=float32),
#   'probabilities': array([0.7155523, 0.2844477], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0640928], dtype=float32),
#   'logistic': array([0.74347186], dtype=float32),
#   'probabilities': array([0.25652808, 0.74347186], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4728539], dtype=float32),
#   'logistic': array([0.18650922], dtype=float32),
#   'probabilities': array([0.8134908 , 0.18650922], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8671113], dtype=float32),
#   'logistic': array([0.13387635], dtype=float32),
#   'probabilities': array([0.8661237 , 0.13387632], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.26465595], dtype=float32),
#   'logistic': array([0.56578046], dtype=float32),
#   'probabilities': array([0.43421954, 0.5657805 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.1295799], dtype=float32),
#   'logistic': array([0.4676503], dtype=float32),
#   'probabilities': array([0.5323497 , 0.46765026], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.5242687], dtype=float32),
#   'logistic': array([0.8211662], dtype=float32),
#   'probabilities': array([0.17883378, 0.8211662 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5043347], dtype=float32),
#   'logistic': array([0.62347746], dtype=float32),
#   'probabilities': array([0.37652254, 0.62347746], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8445473], dtype=float32),
#   'logistic': array([0.13651437], dtype=float32),
#   'probabilities': array([0.8634856 , 0.13651438], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.47702014], dtype=float32),
#   'logistic': array([0.617044], dtype=float32),
#   'probabilities': array([0.38295603, 0.617044  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)}]

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units = [10,10,10],feature_columns = feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\PRAMEE~1\AppData\Local\Temp\tmp78qgvuk2
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\PRAMEE~1\\AppData\\Local\\Temp\\tmp78qgvuk2', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn = input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-030181bc3d48> in <module>
# ----> 1 dnn_model.train(input_fn = input_func,steps=1000)
#
# D:\anaconda\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     347
#     348       saving_listeners = _check_listeners_type(saving_listeners)
# --> 349       loss = self._train_model(input_fn, hooks, saving_listeners)
#     350       logging.info('Loss for final step: %s.', loss)
#     351       return self
#
# D:\anaconda\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1173       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1174     else:
# -> 1175       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1176
#    1177   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# D:\anaconda\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1201           self._get_features_and_labels_from_input_fn(input_fn, ModeKeys.TRAIN))
#    1202       worker_hooks.extend(input_hooks)
# -> 1203       estimator_spec = self._call_model_fn(features, labels, ModeKeys.TRAIN,
#    1204                                            self.config)
#    1205       global_step_tensor = tf.compat.v1.train.get_global_step(g)
#
# D:\anaconda\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1161
#    1162     logging.info('Calling model_fn.')
# -> 1163     model_fn_results = self._model_fn(features=features, **kwargs)
#    1164     logging.info('Done calling model_fn.')
#    1165
#
# D:\anaconda\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in _model_fn(features, labels, mode, config)
#     748     def _model_fn(features, labels, mode, config):
#     749       """Call the defined shared dnn_model_fn_v2."""
# --> 750       return dnn_model_fn_v2(
#     751           features=features,
#     752           labels=labels,
#
# D:\anaconda\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in dnn_model_fn_v2(***failed resolving arguments***)
#     558   del config
#     559
# --> 560   logits, trainable_variables, update_ops = _dnn_model_fn_builder_v2(
#     561       units=head.logits_dimension,
#     562       hidden_units=hidden_units,
#
# D:\anaconda\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in _dnn_model_fn_builder_v2(units, hidden_units, feature_columns, activation_fn, dropout, batch_norm, features, mode)
#     494     raise ValueError('units must be an int.  Given type: {}'.format(
#     495         type(units)))
# --> 496   dnn_model = _DNNModelV2(
#     497       units,
#     498       hidden_units,
#
# D:\anaconda\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in __init__(self, units, hidden_units, feature_columns, activation_fn, dropout, batch_norm, name, **kwargs)
#     291       layer_name = input_feature_column_scope + 'input_layer'
#     292       if feature_column_lib.is_feature_column_v2(feature_columns):
# --> 293         self._input_layer = tf.compat.v2.keras.layers.DenseFeatures(
#     294             feature_columns=feature_columns, name=layer_name)
#     295       else:
#
# D:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\keras\feature_column\dense_features_v2.py in __init__(self, feature_columns, trainable, name, **kwargs)
#      81       ValueError: if an item in `feature_columns` is not a `DenseColumn`.
#      82     """
# ---> 83     super(DenseFeatures, self).__init__(
#      84         feature_columns=feature_columns,
#      85         trainable=trainable,
#
# D:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\keras\feature_column\dense_features.py in __init__(self, feature_columns, trainable, name, partitioner, **kwargs)
#      92       ValueError: if an item in `feature_columns` is not a `DenseColumn`.
#      93     """
# ---> 94     super(DenseFeatures, self).__init__(
#      95         feature_columns=feature_columns,
#      96         trainable=trainable,
#
# D:\anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\keras\feature_column\base_feature_layer.py in __init__(self, feature_columns, expected_column_type, trainable, name, partitioner, **kwargs)
#      65     for column in self._feature_columns:
#      66       if not isinstance(column, expected_column_type):
# ---> 67         raise ValueError(
#      68             'Items of feature_columns must be a {}. '
#      69             'You can wrap a categorical column with an '
#
# ValueError: Items of feature_columns must be a <class 'tensorflow.python.feature_column.feature_column_v2.DenseColumn'>. You can wrap a categorical column with an embedding_column or indicator_column. Given: VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embeded_group_col = tf.feature_column.embedding_column(assigned_group,dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embeded_group_col, age_bucket]

# %%
input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x = X_train,
                                                 y = y_train,
                                                 batch_size = 10,
                                                 num_epochs = 1000,
                                                 shuffle = True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units = [10,20,20,10,10],feature_columns = feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\PRAMEE~1\AppData\Local\Temp\tmp8g76pyqc
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\PRAMEE~1\\AppData\\Local\\Temp\\tmp8g76pyqc', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn = input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\PRAMEE~1\AppData\Local\Temp\tmp8g76pyqc\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.6861633, step = 0
# INFO:tensorflow:global_step/sec: 198.579
# INFO:tensorflow:loss = 0.6780321, step = 100 (0.508 sec)
# INFO:tensorflow:global_step/sec: 234.296
# INFO:tensorflow:loss = 0.69937885, step = 200 (0.425 sec)
# INFO:tensorflow:global_step/sec: 239.867
# INFO:tensorflow:loss = 0.69517297, step = 300 (0.419 sec)
# INFO:tensorflow:global_step/sec: 237.578
# INFO:tensorflow:loss = 0.65315276, step = 400 (0.420 sec)
# INFO:tensorflow:global_step/sec: 206.103
# INFO:tensorflow:loss = 0.6989767, step = 500 (0.489 sec)
# INFO:tensorflow:global_step/sec: 184.353
# INFO:tensorflow:loss = 0.65921724, step = 600 (0.539 sec)
# INFO:tensorflow:global_step/sec: 166.73
# INFO:tensorflow:loss = 0.6796764, step = 700 (0.601 sec)
# INFO:tensorflow:global_step/sec: 149.496
# INFO:tensorflow:loss = 0.70610726, step = 800 (0.668 sec)
# INFO:tensorflow:global_step/sec: 136.791
# INFO:tensorflow:loss = 0.6839164, step = 900 (0.734 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\PRAMEE~1\AppData\Local\Temp\tmp8g76pyqc\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Loss for final step: 0.6458548.

# %%
eval_input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=X_test,
                                                                y=y_test,
                                                                batch_size= 10,
                                                                num_epochs=1,
                                                                shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-06-03T10:55:52Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\PRAMEE~1\AppData\Local\Temp\tmp8g76pyqc\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.91443s
# INFO:tensorflow:Finished evaluation at 2021-06-03-10:55:53
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.64935064, accuracy_baseline = 0.64935064, auc = 0.4485185, auc_precision_recall = 0.31099248, average_loss = 0.6705356, global_step = 1000, label/mean = 0.35064936, loss = 0.67470694, precision = 0.0, prediction/mean = 0.44559106, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\PRAMEE~1\AppData\Local\Temp\tmp8g76pyqc\model.ckpt-1000
# {'accuracy': 0.64935064,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.4485185,
#  'auc_precision_recall': 0.31099248,
#  'average_loss': 0.6705356,
#  'label/mean': 0.35064936,
#  'loss': 0.67470694,
#  'precision': 0.0,
#  'prediction/mean': 0.44559106,
#  'recall': 0.0,
#  'global_step': 1000}
