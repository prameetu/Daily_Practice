# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(seed=1234)

# %%
url = "https://raw.githubusercontent.com/GokuMohandas/madewithml/main/datasets/titanic.csv"
df = pd.read_csv(url,header=0)

# %%
df.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0

# %%
df.describe()
# Out:
#             pclass          age        sibsp        parch         fare  \
# count  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000
# mean      2.294882    29.881135     0.498854     0.385027    33.295479
# std       0.837836    14.413500     1.041658     0.865560    51.758668
# min       1.000000     0.166700     0.000000     0.000000     0.000000
# 25%       2.000000    21.000000     0.000000     0.000000     7.895800
# 50%       3.000000    28.000000     0.000000     0.000000    14.454200
# 75%       3.000000    39.000000     1.000000     0.000000    31.275000
# max       3.000000    80.000000     8.000000     9.000000   512.329200
#
#           survived
# count  1309.000000
# mean      0.381971
# std       0.486055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df['age']
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
df['age'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.hist(df['age'])
# Out:
# (array([ 72.,  62., 274., 250., 161., 108.,  65.,  41.,  10.,   3.]),
#  array([ 0.1667 ,  8.15003, 16.13336, 24.11669, 32.10002, 40.08335,
#         48.06668, 56.05001, 64.03334, 72.01667, 80.     ]),
#  <BarContainer object of 10 artists>)

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
df['name'].head()
# Out:
# 0                      Allen, Miss. Elisabeth Walton
# 1                     Allison, Master. Hudson Trevor
# 2                       Allison, Miss. Helen Loraine
# 3               Allison, Mr. Hudson Joshua Creighton
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# Name: name, dtype: object

# %%
df[df['embarked'] == 'female'].count()
# Out:
# pclass      1309
# name        1309
# sex         1309
# age         1046
# sibsp       1309
# parch       1309
# ticket      1309
# fare        1308
# cabin        295
# embarked    1309
# survived    1309
# female      1309
# dtype: int64

# %%
df.sort_values('age')
# Out:
#       pclass                                     name     sex     age  sibsp  \
# 763        3  Dean, Miss. Elizabeth Gladys "Millvina"  female  0.1667      1
# 747        3  Danbom, Master. Gilbert Sigvard Emanuel    male  0.3333      0
# 1240       3          Thomas, Master. Assad Alexander    male  0.4167      0
# 427        2                Hamalainen, Master. Viljo    male  0.6667      1
# 1111       3           Peacock, Master. Alfred Edward    male  0.7500      1
# ...      ...                                      ...     ...     ...    ...
# 1293       3        Williams, Mr. Howard Hugh "Harry"    male     NaN      0
# 1297       3                   Wiseman, Mr. Phillippe    male     NaN      0
# 1302       3                        Yousif, Mr. Wazli    male     NaN      0
# 1303       3                    Yousseff, Mr. Gerious    male     NaN      0
# 1305       3                    Zabour, Miss. Thamine  female     NaN      1
#
# ...

# %%
df.sort_values('age',ascending=False)
#Sorts the df acc to age in descending manner
# Out:
#       pclass                                               name     sex   age  \
# 14         1               Barkworth, Mr. Algernon Henry Wilson    male  80.0
# 61         1  Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0
# 1235       3                                Svensson, Mr. Johan    male  74.0
# 135        1                          Goldschmidt, Mr. George B    male  71.0
# 9          1                            Artagaveytia, Mr. Ramon    male  71.0
# ...      ...                                                ...     ...   ...
# 1293       3                  Williams, Mr. Howard Hugh "Harry"    male   NaN
# 1297       3                             Wiseman, Mr. Phillippe    male   NaN
# 1302       3                                  Yousif, Mr. Wazli    male   NaN
# 1303       3                              Yousseff, Mr. Gerious    male   NaN
# 1305       3                              Zabour, Miss. Thamine  female   NaN
#
# ...

# %%
survived_group = df.groupby('survived')
survived_group.count()
# Out:
#           pclass  name  sex  age  sibsp  parch  ticket  fare  cabin  embarked  \
# survived
# 0            809   809  809  619    809    809     809   808    102       809
# 1            500   500  500  427    500    500     500   500    193       500
#
#           female
# survived
# 0            809
# 1            500

# %%
df.iloc[0]
# Out:
# pclass                                  1
# name        Allen, Miss. Elisabeth Walton
# sex                                female
# age                                    29
# sibsp                                   0
# parch                                   0
# ticket                              24160
# fare                              211.338
# cabin                                  B5
# embarked                           female
# survived                                1
# female                             female
# Name: 0, dtype: object

# %%
df.dropna()
df.reset_index()
# Out:
#       index  pclass                                             name     sex  \
# 0         0       1                    Allen, Miss. Elisabeth Walton  female
# 1         1       1                   Allison, Master. Hudson Trevor    male
# 2         2       1                     Allison, Miss. Helen Loraine  female
# 3         3       1             Allison, Mr. Hudson Joshua Creighton    male
# 4         4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...     ...     ...                                              ...     ...
# 1304   1304       3                             Zabour, Miss. Hileni  female
# 1305   1305       3                            Zabour, Miss. Thamine  female
# 1306   1306       3                        Zakarian, Mr. Mapriededer    male
# 1307   1307       3                              Zakarian, Mr. Ortin    male
# 1308   1308       3                               Zimmerman, Mr. Leo    male
#
# ...

# %%
df.drop(['name','cabin','ticket'],axis=1)
# Out:
#       pclass     sex      age  sibsp  parch      fare embarked  survived  \
# 0          1  female  29.0000      0      0  211.3375   female         1
# 1          1    male   0.9167      1      2  151.5500   female         1
# 2          1  female   2.0000      1      2  151.5500   female         0
# 3          1    male  30.0000      1      2  151.5500   female         0
# 4          1  female  25.0000      1      2  151.5500   female         0
# ...      ...     ...      ...    ...    ...       ...      ...       ...
# 1304       3  female  14.5000      1      0   14.4542   female         0
# 1305       3  female      NaN      1      0   14.4542   female         0
# 1306       3    male  26.5000      0      0    7.2250   female         0
# 1307       3    male  27.0000      0      0    7.2250   female         0
# 1308       3    male  29.0000      0      0    7.8750   female         0
#
#       female
# 0     female
# 1     female
# 2     female
# 3     female
# 4     female
# ...

# %%
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived  \
# ...

# %%
def get_family_size(sibsp,parch):
    family_size = sibsp + parch
    return family_size

# %%
df['family_size'] = df[['sibsp','parch']].apply(lambda x:get_family_size(x['sibsp'],x['parch']),axis=1)
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived  \
# ...
